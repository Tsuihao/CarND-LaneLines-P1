# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
#
# ## Project: **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# In addition to implementing code, there is a brief writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) that can be used to guide the writing process. Completing both the code in the Ipython notebook and the writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/322/view) for this project.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %% [markdown]
# **Run the cell below to import some packages.  If you get an `import error` for a package you've already installed, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt.  Also, consult the forums for more troubleshooting tips.**

# %% [markdown]
# ## Import Packages

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# ## Read in an Image

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Ideas for Lane Detection Pipeline

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

def is_left_lane(line):
    res = False
    
    # Extract points x1,y1,x2,y2 in HoughLineP
    x1 = line[0][0]
    y1 = line[0][1]
    x2 = line[0][2]
    y2 = line[0][3]
    
    if(x2-x1 != 0):
        m = (y2-y1)/(x2-x1)
        if m > 0:
            res = True
            
    return res

def is_lane(line, slope_low, slope_high):
    """
    Arg:
    [Input]: 
        line: A single lane (output from cv.HoughLinesP)
        slope_low: slope low threshold
        slope_high: slope high threshold
        
    [Return]:
        bool: True (Belong to the specific cetogory of lane)
    
    Here the assumption is: the left or right lanes has the same slope at each section of lane.
    Short-comming: The curvature sceanrio
    """
    res = False
    
    # Extract points x1,y1,x2,y2 in HoughLineP
    x1 = line[0][0]
    y1 = line[0][1]
    x2 = line[0][2]
    y2 = line[0][3]
    
    if(x2-x1 != 0):
        m = (y2-y1)/(x2-x1)
        if(m > slope_low and m < slope_high):
            res = True

    return res
    
def extract_top_n_bottom_point(lines):
    """
    Arg:
    [Input]:
        lines: Either left or right lane
        
    [Output]:
        top_point, bottom_point: From either left or right lane.
    
    Based on the input lines, extract the most upper point and the most bottom point
    Here the assumption is: the left or right lanes has the same slope at each section of lane.
    Short-comming: The curvature sceanrio
    """
    bottom_point = (lines[0][0][0], lines[0][0][1])  # Init with (x1,y1)
    top_point = (lines[0][0][0], lines[0][0][1])
    
    for line in lines:
        for x1,y1,x2,y2 in line: # y2 > y1             
            if(y1 < bottom_point[1]):
                bottom_point = (x1, y1)
            if(y2 > top_point[1]):
                top_point = (x2, y2)
            
    return bottom_point, top_point

def draw_lines(img, lines, color=[255, 0, 0], thickness=8):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    # TODO: extropolate here
    left_lane = []
    left_slope_low = 20/32 
    left_slope_high = 28/32
    
    right_lane = []
    right_slope_low = -28/32
    right_slope_high = -20/32
    
    for line in lines:    
        # categorize into left and right lane
        #if(is_lane(line, left_slope_low, left_slope_high)):
        #    left_lane.append(line)
        #    continue #each line only belong to one category (left/right/nothing)
            
        #if(is_lane(line, right_slope_low, right_slope_high)):
        #    right_lane.append(line)
        #    continue
        if(is_left_lane(line)):
            left_lane.append(line)
        else:
            right_lane.append(line)
        
        
    # Tracing   
    print("Original number of lane {}". format(lines.size))
    print("Left lane line {}".format(len(left_lane)))
    print("Right lane line {}".format(len(right_lane)))    
    
    # Extract top and bottom point
    left_bottom, left_top = extract_top_n_bottom_point(left_lane)
    right_bottom, right_top = extract_top_n_bottom_point(right_lane)
    
    # Draw
    cv2.line(img, (left_bottom[0], left_bottom[1]), (left_top[0], left_top[1]), color, thickness) # Left
    cv2.line(img, (right_bottom[0], right_bottom[1]), (right_top[0], right_top[1]), color, thickness) # Right
    

def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., γ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + γ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, γ)

# %% [markdown]
# ## Test Images
#
# Build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
# Out:
# ['solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %% [markdown]
# ## Build a Lane Finding Pipeline

# %% [markdown]
# Build the pipeline and run your solution on all test_images. Make copies into the `test_images_output` directory, and you can use the images in your writeup report.
#
# Try tuning the various parameters, especially the low and high Canny thresholds as well as the Hough lines parameters.

# %% [markdown]
# ### Pipeline
# The pipeline consisted of the following steps:
# 1. [Pre-processing]: convert image into gray scale and blur it with Gaussian filter.
# 2. Use Canny edge detection to extract the contour.
# 3. Implement Region of Interests (ROI) and Hough transform to extract potential line.
# 4. [Post-processing]: colorize the detected lane and extropolate the dash-line into solid line.
# 5. [Post-processing]: use cv2.addWeighted function to overlap the mask and original image.

# %%
# TODO: Build your pipeline that will draw lane lines on the test_images
# then save them to the test_images_output directory.

# %%
# Read image
#ori_img = mpimg.imread('test_images/solidWhiteRight.jpg')
ori_img = mpimg.imread('test_images/whiteCarLaneSwitch.jpg')
h = ori_img.shape[0]
w = ori_img.shape[1]
print('height: {}, width: {}'.format(h, w))

plt.subplot(131),plt.imshow(ori_img)
plt.title('Original'), plt.xticks([]), plt.yticks([])

# 1:[Pre-processing]: convert image into gray scale and blur it with Gaussian filter.
gray_img = grayscale(ori_img)
plt.subplot(132),plt.imshow(gray_img, cmap='gray')
plt.title('Gray'), plt.xticks([]), plt.yticks([])

blurred_gray_img = gaussian_blur(gray_img, 5)
plt.subplot(133),plt.imshow(blurred_gray_img, cmap='gray')
plt.title('Blured'), plt.xticks([]), plt.yticks([])
plt.show()

# 2. Use Canny edge detection to extract the contour.
edges = canny(blurred_gray_img, 50, 150)
plt.imshow(edges, cmap='gray')
plt.title('Edges'), plt.xticks([]), plt.yticks([])
plt.show()

# 3. Implement Region of Interests (ROI) and Hough transform to extract potential line.
ROI = np.array([[(50, h), (450, 320), (490, 320), (w-50, h)]], dtype=np.int32)
masked_img = region_of_interest(edges, ROI)
plt.imshow(masked_img, cmap='gray')
plt.title('ROI'), plt.xticks([]), plt.yticks([])
plt.show()

# Define the Hough transform parameters
rho = 1                         # distance resolution in pixels of the Hough grid
theta = np.pi/180               # angular resolution in radians of the Hough grid
threshold = 2                   # minimum number of votes (intersections in Hough grid cell)
min_line_length = 5             # minimum number of pixels making up a line
max_line_gap = 50               # maximum gap in pixels between connectable line segments

# 4. [Post-processing]: colorize the detected lane and extropolate the dash-line into solid line.
line_img = hough_lines(masked_img, rho, theta, threshold, min_line_length, max_line_gap)
plt.imshow(line_img, cmap='gray')
plt.title('line'), plt.xticks([]), plt.yticks([])
plt.show()

# 5. [Post-processing]: use cv2.addWeighted function to overlap the mask and original image.
overlapped_img = weighted_img(line_img, ori_img)
plt.imshow(overlapped_img)
plt.title('Overlapped'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# height: 540, width: 960
# Original number of lane 888
# Left lane line 84
# Right lane line 138

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an import error when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel). Still have problems? Try relaunching Jupyter Notebook from the terminal prompt. Also, consult the forums for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://discussions.udacity.com/t/project-error-of-test-on-videos/274082) for more troubleshooting tips across operating systems.**

# %%
# Run this if you have the error
#import imcageio
#imageio.plugins.ffmpeg.download()

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def lane_detection(image):
    # 1:[Pre-processing]: convert image into gray scale and blur it with Gaussian filter.
    gray_img = grayscale(image)
    blurred_gray_img = gaussian_blur(gray_img, 5)

    # 2. Use Canny edge detection to extract the contour.
    edges = canny(blurred_gray_img, 50, 150)

    # 3. Implement Region of Interests (ROI) and Hough transform to extract potential line.
    ROI = np.array([[(50, h), (450, 320), (490, 320), (w-50, h)]], dtype=np.int32)
    masked_img = region_of_interest(edges, ROI)

    # Define the Hough transform parameters
    rho = 1                         # distance resolution in pixels of the Hough grid
    theta = np.pi/180               # angular resolution in radians of the Hough grid
    threshold = 20                   # minimum number of votes (intersections in Hough grid cell)
    min_line_length = 3             # minimum number of pixels making up a line
    max_line_gap = 10               # maximum gap in pixels between connectable line segments

    # 4. [Post-processing]: colorize the detected lane and extropolate the dash-line into solid line.
    line_img = hough_lines(masked_img, rho, theta, threshold, min_line_length, max_line_gap)


    # 5. [Post-processing]: use cv2.addWeighted function to overlap the mask and original image.
    overlapped_img = weighted_img(line_img, image)

    return overlapped_img

# %%
def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    result = lane_detection(image)
    return result

# %%
image = mpimg.imread('test_images/whiteCarLaneSwitch.jpg')
#image = (mpimg.imread('test_images/whiteCarLaneSwitch.jpg') * 255).astype('uint8')
#image = 'test_images/whiteCarLaneSwitch.jpg'
processImg = process_image(image)
plt.imshow(processImg)
plt.show()
# Out:
# Original number of lane 76
# Left lane line 7
# Right lane line 12

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'solidWhiteRight.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
clip1 = VideoFileClip("test_videos\solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-03cdda2abd5b> in <module>()
#       5 ## You may also uncomment the following line for a subclip of the first 5 seconds
#       6 ##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
# ----> 7 clip1 = VideoFileClip("test_videos\solidWhiteRight.mp4")
#       8 white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
#       9 get_ipython().magic('time white_clip.write_videofile(white_output, audio=False)')
#
# D:\Anaconda3\lib\site-packages\moviepy\video\io\VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      79                                          target_resolution=target_resolution,
#      80                                          resize_algo=resize_algorithm,
# ---> 81                                          fps_source=fps_source)
#      82
#      83         # Make some of the reader's attributes accessible from the clip
#
# D:\Anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_reader.py in __init__(self, filename, print_infos, bufsize, pix_fmt, check_duration, target_resolution, resize_algo, fps_source)
#      30         self.filename = filename
#      31         infos = ffmpeg_parse_infos(filename, print_infos, check_duration,
# ---> 32                                    fps_source)
#      33         self.fps = infos['video_fps']
#      34         self.size = infos['video_size']
#
# D:\Anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_reader.py in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     254         popen_params["creationflags"] = 0x08000000
#     255
# --> 256     proc = sp.Popen(cmd, **popen_params)
#     257
#     258     proc.stdout.readline()
#
# D:\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     592                  pass_fds=(), *, encoding=None, errors=None):
#     593         """Create new Popen instance."""
# --> 594         _cleanup()
#     595         # Held while anything is calling waitpid before returncode has been
#     596         # updated to prevent clobbering returncode if wait() or poll() are
#
# D:\Anaconda3\lib\subprocess.py in _cleanup()
#     203 def _cleanup():
#     204     for inst in _active[:]:
# --> 205         res = inst._internal_poll(_deadstate=sys.maxsize)
#     206         if res is not None:
#     207             try:
#
# D:\Anaconda3\lib\subprocess.py in _internal_poll(self, _deadstate, _WaitForSingleObject, _WAIT_OBJECT_0, _GetExitCodeProcess)
#    1025             """
#    1026             if self.returncode is None:
# -> 1027                 if _WaitForSingleObject(self._handle, 0) == _WAIT_OBJECT_0:
#    1028                     self.returncode = _GetExitCodeProcess(self._handle)
#    1029             return self.returncode
#
# OSError: [WinError 6] The handle is invalid

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="solidWhiteRight.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'solidYellowLeft.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4').subclip(0,5)
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False);
# Out:
# Original number of lane 64
# Left lane line 6
# Right lane line 10
# [MoviePy] >>>> Building video solidYellowLeft.mp4
# [MoviePy] Writing video solidYellowLeft.mp4
#   0%|                                                                                                                                  | 0/682 [00:00<?, ?it/s]
# Original number of lane 64
# Left lane line 6
# Right lane line 10
# Original number of lane 80
# Left lane line 10
# Right lane line 10
# Original number of lane 96
# Left lane line 9
# Right lane line 15
#   0%|▌                                                                                                                         | 3/682 [00:00<00:25, 26.32it/s]
# Original number of lane 84
# Left lane line 10
# Right lane line 11
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 68
# Left lane line 3
# Right lane line 14
# Original number of lane 60
# Left lane line 4
# Right lane line 11
# Original number of lane 68
# Left lane line 3
# Right lane line 14
#   1%|█▍                                                                                                                        | 8/682 [00:00<00:22, 30.51it/s]
# Original number of lane 64
# Left lane line 4
# Right lane line 12
# Original number of lane 64
# Left lane line 4
# Right lane line 12
# Original number of lane 72
# Left lane line 5
# Right lane line 13
# Original number of lane 76
# Left lane line 7
# Right lane line 12
# Original number of lane 80
# Left lane line 8
# Right lane line 12
# Original number of lane 100
# Left lane line 9
# Right lane line 16
#   2%|██▍                                                                                                                      | 14/682 [00:00<00:19, 34.43it/s]
# Original number of lane 112
# Left lane line 8
# Right lane line 20
# Original number of lane 76
# Left lane line 7
# Right lane line 12
# Original number of lane 84
# Left lane line 8
# Right lane line 13
# Original number of lane 64
# Left lane line 5
# Right lane line 11
# Original number of lane 40
# Left lane line 3
# Right lane line 7
#   3%|███▎                                                                                                                     | 19/682 [00:00<00:17, 37.13it/s]
# Original number of lane 48
# Left lane line 3
# Right lane line 9
# Original number of lane 60
# Left lane line 5
# Right lane line 10
# Original number of lane 68
# Left lane line 4
# Right lane line 13
# Original number of lane 52
# Left lane line 4
# Right lane line 9
# Original number of lane 64
# Left lane line 6
# Right lane line 10
#   4%|████▎                                                                                                                    | 24/682 [00:00<00:16, 40.24it/s]
# Original number of lane 72
# Left lane line 5
# Right lane line 13
# Original number of lane 80
# Left lane line 10
# Right lane line 10
# Original number of lane 100
# Left lane line 14
# Right lane line 11
# Original number of lane 92
# Left lane line 10
# Right lane line 13
# Original number of lane 68
# Left lane line 7
# Right lane line 10
#   4%|█████▏                                                                                                                   | 29/682 [00:00<00:15, 41.99it/s]
# Original number of lane 76
# Left lane line 6
# Right lane line 13
# Original number of lane 76
# Left lane line 1
# Right lane line 18
# Original number of lane 60
# Left lane line 1
# Right lane line 14
# Original number of lane 44
# Left lane line 1
# Right lane line 10
# Original number of lane 52
# Left lane line 1
# Right lane line 12
#   5%|██████                                                                                                                   | 34/682 [00:00<00:15, 42.42it/s]
# Original number of lane 76
# Left lane line 4
# Right lane line 15
# Original number of lane 76
# Left lane line 4
# Right lane line 15
# Original number of lane 84
# Left lane line 6
# Right lane line 15
# Original number of lane 72
# Left lane line 5
# Right lane line 13
# Original number of lane 68
# Left lane line 6
# Right lane line 11
#   6%|██████▉                                                                                                                  | 39/682 [00:00<00:15, 42.09it/s]
# Original number of lane 76
# Left lane line 5
# Right lane line 14
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 76
# Left lane line 4
# Right lane line 15
# Original number of lane 56
# Left lane line 1
# Right lane line 13
# Original number of lane 52
# Left lane line 1
# Right lane line 12
#   6%|███████▊                                                                                                                 | 44/682 [00:01<00:15, 40.83it/s]
# Original number of lane 36
# Left lane line 1
# Right lane line 8
# Original number of lane 56
# Left lane line 2
# Right lane line 12
# Original number of lane 64
# Left lane line 4
# Right lane line 12
# Original number of lane 52
# Left lane line 3
# Right lane line 10
# Original number of lane 56
# Left lane line 3
# Right lane line 11
#   7%|████████▋                                                                                                                | 49/682 [00:01<00:16, 39.06it/s]
# Original number of lane 56
# Left lane line 4
# Right lane line 10
# Original number of lane 60
# Left lane line 5
# Right lane line 10
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 72
# Left lane line 10
# Right lane line 8
#   8%|█████████▍                                                                                                               | 53/682 [00:01<00:16, 38.10it/s]
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 56
# Left lane line 5
# Right lane line 9
# Original number of lane 48
# Left lane line 1
# Right lane line 11
# Original number of lane 52
# Left lane line 3
# Right lane line 10
#   8%|██████████                                                                                                               | 57/682 [00:01<00:16, 38.54it/s]
# Original number of lane 48
# Left lane line 3
# Right lane line 9
# Original number of lane 48
# Left lane line 4
# Right lane line 8
# Original number of lane 48
# Left lane line 3
# Right lane line 9
# Original number of lane 72
# Left lane line 5
# Right lane line 13
#   9%|██████████▊                                                                                                              | 61/682 [00:01<00:16, 38.29it/s]
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 52
# Left lane line 4
# Right lane line 9
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 72
# Left lane line 9
# Right lane line 9
#  10%|███████████▌                                                                                                             | 65/682 [00:01<00:16, 37.59it/s]
# Original number of lane 88
# Left lane line 10
# Right lane line 12
# Original number of lane 64
# Left lane line 6
# Right lane line 10
# Original number of lane 68
# Left lane line 6
# Right lane line 11
# Original number of lane 56
# Left lane line 3
# Right lane line 11
#  10%|████████████▏                                                                                                            | 69/682 [00:01<00:16, 36.70it/s]
# Original number of lane 68
# Left lane line 4
# Right lane line 13
# Original number of lane 72
# Left lane line 4
# Right lane line 14
# Original number of lane 68
# Left lane line 6
# Right lane line 11
# Original number of lane 68
# Left lane line 6
# Right lane line 11
#  11%|████████████▉                                                                                                            | 73/682 [00:01<00:16, 36.60it/s]
# Original number of lane 64
# Left lane line 6
# Right lane line 10
# Original number of lane 76
# Left lane line 7
# Right lane line 12
# Original number of lane 100
# Left lane line 8
# Right lane line 17
# Original number of lane 88
# Left lane line 12
# Right lane line 10
#  11%|█████████████▋                                                                                                           | 77/682 [00:01<00:16, 37.14it/s]
# Original number of lane 76
# Left lane line 10
# Right lane line 9
# Original number of lane 96
# Left lane line 9
# Right lane line 15
# Original number of lane 68
# Left lane line 8
# Right lane line 9
# Original number of lane 56
# Left lane line 2
# Right lane line 12
#  12%|██████████████▎                                                                                                          | 81/682 [00:02<00:16, 36.70it/s]
# Original number of lane 56
# Left lane line 4
# Right lane line 10
# Original number of lane 48
# Left lane line 2
# Right lane line 10
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 56
# Left lane line 5
# Right lane line 9
#  12%|███████████████                                                                                                          | 85/682 [00:02<00:16, 36.80it/s]
# Original number of lane 76
# Left lane line 6
# Right lane line 13
# Original number of lane 52
# Left lane line 5
# Right lane line 8
# Original number of lane 60
# Left lane line 7
# Right lane line 8
# Original number of lane 68
# Left lane line 9
# Right lane line 8
#  13%|███████████████▊                                                                                                         | 89/682 [00:02<00:16, 36.57it/s]
# Original number of lane 92
# Left lane line 10
# Right lane line 13
# Original number of lane 100
# Left lane line 17
# Right lane line 8
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 108
# Left lane line 17
# Right lane line 10
#  14%|████████████████▌                                                                                                        | 93/682 [00:02<00:16, 36.71it/s]
# Original number of lane 60
# Left lane line 5
# Right lane line 10
# Original number of lane 56
# Left lane line 7
# Right lane line 7
# Original number of lane 76
# Left lane line 7
# Right lane line 12
# Original number of lane 64
# Left lane line 5
# Right lane line 11
#  14%|█████████████████▏                                                                                                       | 97/682 [00:02<00:15, 37.43it/s]
# Original number of lane 68
# Left lane line 8
# Right lane line 9
# Original number of lane 72
# Left lane line 6
# Right lane line 12
# Original number of lane 64
# Left lane line 5
# Right lane line 11
# Original number of lane 80
# Left lane line 7
# Right lane line 13
#  15%|█████████████████▊                                                                                                      | 101/682 [00:02<00:15, 38.05it/s]
# Original number of lane 80
# Left lane line 8
# Right lane line 12
# Original number of lane 100
# Left lane line 10
# Right lane line 15
# Original number of lane 80
# Left lane line 10
# Right lane line 10
# Original number of lane 76
# Left lane line 12
# Right lane line 7
#  15%|██████████████████▍                                                                                                     | 105/682 [00:02<00:15, 36.91it/s]
# Original number of lane 84
# Left lane line 7
# Right lane line 14
# Original number of lane 72
# Left lane line 6
# Right lane line 12
# Original number of lane 64
# Left lane line 6
# Right lane line 10
# Original number of lane 68
# Left lane line 8
# Right lane line 9
#  16%|███████████████████▏                                                                                                    | 109/682 [00:02<00:15, 37.26it/s]
# Original number of lane 68
# Left lane line 6
# Right lane line 11
# Original number of lane 88
# Left lane line 7
# Right lane line 15
# Original number of lane 68
# Left lane line 6
# Right lane line 11
# Original number of lane 76
# Left lane line 6
# Right lane line 13
#  17%|███████████████████▉                                                                                                    | 113/682 [00:02<00:16, 35.51it/s]
# Original number of lane 84
# Left lane line 8
# Right lane line 13
# Original number of lane 68
# Left lane line 6
# Right lane line 11
# Original number of lane 88
# Left lane line 9
# Right lane line 13
# Original number of lane 76
# Left lane line 10
# Right lane line 9
#  17%|████████████████████▌                                                                                                   | 117/682 [00:03<00:15, 36.15it/s]
# Original number of lane 88
# Left lane line 8
# Right lane line 14
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 68
# Left lane line 7
# Right lane line 10
# Original number of lane 76
# Left lane line 5
# Right lane line 14
#  18%|█████████████████████▎                                                                                                  | 121/682 [00:03<00:15, 35.44it/s]
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 68
# Left lane line 6
# Right lane line 11
# Original number of lane 60
# Left lane line 6
# Right lane line 9
#  18%|█████████████████████▉                                                                                                  | 125/682 [00:03<00:15, 36.70it/s]
# Original number of lane 52
# Left lane line 5
# Right lane line 8
# Original number of lane 68
# Left lane line 9
# Right lane line 8
# Original number of lane 88
# Left lane line 13
# Right lane line 9
# Original number of lane 64
# Left lane line 9
# Right lane line 7
#  19%|██████████████████████▋                                                                                                 | 129/682 [00:03<00:15, 36.10it/s]
# Original number of lane 80
# Left lane line 10
# Right lane line 10
# Original number of lane 72
# Left lane line 10
# Right lane line 8
# Original number of lane 52
# Left lane line 5
# Right lane line 8
# Original number of lane 52
# Left lane line 5
# Right lane line 8
#  20%|███████████████████████▍                                                                                                | 133/682 [00:03<00:14, 36.88it/s]
# Original number of lane 64
# Left lane line 8
# Right lane line 8
# Original number of lane 48
# Left lane line 5
# Right lane line 7
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 48
# Left lane line 6
# Right lane line 6
#  20%|████████████████████████                                                                                                | 137/682 [00:03<00:14, 36.72it/s]
# Original number of lane 56
# Left lane line 5
# Right lane line 9
# Original number of lane 64
# Left lane line 8
# Right lane line 8
# Original number of lane 64
# Left lane line 8
# Right lane line 8
# Original number of lane 76
# Left lane line 11
# Right lane line 8
#  21%|████████████████████████▊                                                                                               | 141/682 [00:03<00:15, 35.26it/s]
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 80
# Left lane line 8
# Right lane line 12
# Original number of lane 64
# Left lane line 6
# Right lane line 10
# Original number of lane 56
# Left lane line 5
# Right lane line 9
#  21%|█████████████████████████▌                                                                                              | 145/682 [00:03<00:15, 35.77it/s]
# Original number of lane 52
# Left lane line 4
# Right lane line 9
# Original number of lane 56
# Left lane line 6
# Right lane line 8
# Original number of lane 56
# Left lane line 7
# Right lane line 7
# Original number of lane 80
# Left lane line 7
# Right lane line 13
#  22%|██████████████████████████▏                                                                                             | 149/682 [00:03<00:14, 36.74it/s]
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 96
# Left lane line 11
# Right lane line 13
# Original number of lane 80
# Left lane line 10
# Right lane line 10
# Original number of lane 108
# Left lane line 14
# Right lane line 13
#  22%|██████████████████████████▉                                                                                             | 153/682 [00:04<00:14, 37.24it/s]
# Original number of lane 88
# Left lane line 11
# Right lane line 11
# Original number of lane 104
# Left lane line 15
# Right lane line 11
# Original number of lane 96
# Left lane line 11
# Right lane line 13
# Original number of lane 76
# Left lane line 10
# Right lane line 9
#  23%|███████████████████████████▌                                                                                            | 157/682 [00:04<00:14, 37.18it/s]
# Original number of lane 84
# Left lane line 11
# Right lane line 10
# Original number of lane 112
# Left lane line 15
# Right lane line 13
# Original number of lane 116
# Left lane line 14
# Right lane line 15
# Original number of lane 108
# Left lane line 15
# Right lane line 12
#  24%|████████████████████████████▎                                                                                           | 161/682 [00:04<00:14, 36.93it/s]
# Original number of lane 100
# Left lane line 11
# Right lane line 14
# Original number of lane 92
# Left lane line 10
# Right lane line 13
# Original number of lane 88
# Left lane line 12
# Right lane line 10
# Original number of lane 120
# Left lane line 18
# Right lane line 12
#  24%|█████████████████████████████                                                                                           | 165/682 [00:04<00:14, 35.68it/s]
# Original number of lane 96
# Left lane line 13
# Right lane line 11
# Original number of lane 88
# Left lane line 13
# Right lane line 9
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 84
# Left lane line 5
# Right lane line 16
#  25%|█████████████████████████████▋                                                                                          | 169/682 [00:04<00:14, 35.78it/s]
# Original number of lane 60
# Left lane line 5
# Right lane line 10
# Original number of lane 64
# Left lane line 5
# Right lane line 11
# Original number of lane 64
# Left lane line 4
# Right lane line 12
# Original number of lane 68
# Left lane line 4
# Right lane line 13
#  25%|██████████████████████████████▍                                                                                         | 173/682 [00:04<00:14, 36.05it/s]
# Original number of lane 64
# Left lane line 6
# Right lane line 10
# Original number of lane 76
# Left lane line 8
# Right lane line 11
# Original number of lane 60
# Left lane line 5
# Right lane line 10
# Original number of lane 80
# Left lane line 9
# Right lane line 11
#  26%|███████████████████████████████▏                                                                                        | 177/682 [00:04<00:14, 34.73it/s]
# Original number of lane 76
# Left lane line 11
# Right lane line 8
# Original number of lane 92
# Left lane line 10
# Right lane line 13
# Original number of lane 72
# Left lane line 9
# Right lane line 9
# Original number of lane 88
# Left lane line 8
# Right lane line 14
#  27%|███████████████████████████████▊                                                                                        | 181/682 [00:04<00:14, 34.75it/s]
# Original number of lane 40
# Left lane line 3
# Right lane line 7
# Original number of lane 48
# Left lane line 2
# Right lane line 10
# Original number of lane 60
# Left lane line 5
# Right lane line 10
# Original number of lane 60
# Left lane line 6
# Right lane line 9
#  27%|████████████████████████████████▌                                                                                       | 185/682 [00:04<00:13, 36.17it/s]
# Original number of lane 76
# Left lane line 10
# Right lane line 9
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 64
# Left lane line 8
# Right lane line 8
# Original number of lane 112
# Left lane line 14
# Right lane line 14
#  28%|█████████████████████████████████▎                                                                                      | 189/682 [00:05<00:13, 35.84it/s]
# Original number of lane 96
# Left lane line 15
# Right lane line 9
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 116
# Left lane line 18
# Right lane line 11
# Original number of lane 92
# Left lane line 13
# Right lane line 10
#  28%|█████████████████████████████████▉                                                                                      | 193/682 [00:05<00:16, 28.96it/s]
# Original number of lane 76
# Left lane line 10
# Right lane line 9
# Original number of lane 56
# Left lane line 6
# Right lane line 8
# Original number of lane 60
# Left lane line 8
# Right lane line 7
# Original number of lane 84
# Left lane line 11
# Right lane line 10
#  29%|██████████████████████████████████▋                                                                                     | 197/682 [00:05<00:15, 30.99it/s]
# Original number of lane 96
# Left lane line 14
# Right lane line 10
# Original number of lane 92
# Left lane line 13
# Right lane line 10
# Original number of lane 100
# Left lane line 14
# Right lane line 11
# Original number of lane 84
# Left lane line 12
# Right lane line 9
# Original number of lane 104
# Left lane line 15
# Right lane line 11
#  30%|███████████████████████████████████▌                                                                                    | 202/682 [00:05<00:14, 33.30it/s]
# Original number of lane 120
# Left lane line 18
# Right lane line 12
# Original number of lane 112
# Left lane line 18
# Right lane line 10
# Original number of lane 116
# Left lane line 17
# Right lane line 12
# Original number of lane 120
# Left lane line 20
# Right lane line 10
#  30%|████████████████████████████████████▏                                                                                   | 206/682 [00:05<00:13, 34.34it/s]
# Original number of lane 84
# Left lane line 12
# Right lane line 9
# Original number of lane 84
# Left lane line 12
# Right lane line 9
# Original number of lane 88
# Left lane line 14
# Right lane line 8
# Original number of lane 108
# Left lane line 17
# Right lane line 10
#  31%|████████████████████████████████████▉                                                                                   | 210/682 [00:05<00:13, 34.56it/s]
# Original number of lane 88
# Left lane line 15
# Right lane line 7
# Original number of lane 84
# Left lane line 15
# Right lane line 6
# Original number of lane 96
# Left lane line 16
# Right lane line 8
# Original number of lane 92
# Left lane line 14
# Right lane line 9
#  31%|█████████████████████████████████████▋                                                                                  | 214/682 [00:05<00:13, 34.63it/s]
# Original number of lane 128
# Left lane line 22
# Right lane line 10
# Original number of lane 124
# Left lane line 22
# Right lane line 9
# Original number of lane 100
# Left lane line 17
# Right lane line 8
# Original number of lane 104
# Left lane line 17
# Right lane line 9
#  32%|██████████████████████████████████████▎                                                                                 | 218/682 [00:05<00:13, 35.22it/s]
# Original number of lane 96
# Left lane line 14
# Right lane line 10
# Original number of lane 80
# Left lane line 13
# Right lane line 7
# Original number of lane 104
# Left lane line 14
# Right lane line 12
# Original number of lane 100
# Left lane line 16
# Right lane line 9
#  33%|███████████████████████████████████████                                                                                 | 222/682 [00:05<00:12, 36.43it/s]
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 108
# Left lane line 16
# Right lane line 11
# Original number of lane 84
# Left lane line 13
# Right lane line 8
# Original number of lane 80
# Left lane line 13
# Right lane line 7
#  33%|███████████████████████████████████████▊                                                                                | 226/682 [00:06<00:12, 36.21it/s]
# Original number of lane 100
# Left lane line 14
# Right lane line 11
# Original number of lane 112
# Left lane line 16
# Right lane line 12
# Original number of lane 92
# Left lane line 15
# Right lane line 8
# Original number of lane 88
# Left lane line 12
# Right lane line 10
# Original number of lane 68
# Left lane line 8
# Right lane line 9
#  34%|████████████████████████████████████████▋                                                                               | 231/682 [00:06<00:11, 37.61it/s]
# Original number of lane 72
# Left lane line 8
# Right lane line 10
# Original number of lane 76
# Left lane line 10
# Right lane line 9
# Original number of lane 72
# Left lane line 11
# Right lane line 7
# Original number of lane 72
# Left lane line 10
# Right lane line 8
#  34%|█████████████████████████████████████████▎                                                                              | 235/682 [00:06<00:12, 36.71it/s]
# Original number of lane 92
# Left lane line 12
# Right lane line 11
# Original number of lane 96
# Left lane line 10
# Right lane line 14
# Original number of lane 88
# Left lane line 11
# Right lane line 11
# Original number of lane 104
# Left lane line 13
# Right lane line 13
#  35%|██████████████████████████████████████████                                                                              | 239/682 [00:06<00:12, 35.92it/s]
# Original number of lane 112
# Left lane line 17
# Right lane line 11
# Original number of lane 92
# Left lane line 15
# Right lane line 8
# Original number of lane 88
# Left lane line 14
# Right lane line 8
# Original number of lane 100
# Left lane line 14
# Right lane line 11
#  36%|██████████████████████████████████████████▊                                                                             | 243/682 [00:06<00:12, 36.35it/s]
# Original number of lane 68
# Left lane line 6
# Right lane line 11
# Original number of lane 88
# Left lane line 12
# Right lane line 10
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 72
# Left lane line 10
# Right lane line 8
#  36%|███████████████████████████████████████████▍                                                                            | 247/682 [00:06<00:11, 36.55it/s]
# Original number of lane 84
# Left lane line 12
# Right lane line 9
# Original number of lane 96
# Left lane line 13
# Right lane line 11
# Original number of lane 88
# Left lane line 11
# Right lane line 11
# Original number of lane 104
# Left lane line 15
# Right lane line 11
#  37%|████████████████████████████████████████████▏                                                                           | 251/682 [00:06<00:11, 37.31it/s]
# Original number of lane 128
# Left lane line 18
# Right lane line 14
# Original number of lane 104
# Left lane line 17
# Right lane line 9
# Original number of lane 116
# Left lane line 17
# Right lane line 12
# Original number of lane 140
# Left lane line 22
# Right lane line 13
#  37%|████████████████████████████████████████████▊                                                                           | 255/682 [00:06<00:11, 37.76it/s]
# Original number of lane 148
# Left lane line 24
# Right lane line 13
# Original number of lane 132
# Left lane line 18
# Right lane line 15
# Original number of lane 88
# Left lane line 14
# Right lane line 8
# Original number of lane 72
# Left lane line 11
# Right lane line 7
#  38%|█████████████████████████████████████████████▌                                                                          | 259/682 [00:06<00:11, 38.29it/s]
# Original number of lane 88
# Left lane line 12
# Right lane line 10
# Original number of lane 72
# Left lane line 12
# Right lane line 6
# Original number of lane 88
# Left lane line 15
# Right lane line 7
# Original number of lane 76
# Left lane line 12
# Right lane line 7
#  39%|██████████████████████████████████████████████▎                                                                         | 263/682 [00:07<00:11, 36.96it/s]
# Original number of lane 80
# Left lane line 12
# Right lane line 8
# Original number of lane 84
# Left lane line 12
# Right lane line 9
# Original number of lane 92
# Left lane line 12
# Right lane line 11
# Original number of lane 76
# Left lane line 13
# Right lane line 6
#  39%|██████████████████████████████████████████████▉                                                                         | 267/682 [00:07<00:11, 36.18it/s]
# Original number of lane 88
# Left lane line 13
# Right lane line 9
# Original number of lane 96
# Left lane line 17
# Right lane line 7
# Original number of lane 96
# Left lane line 14
# Right lane line 10
# Original number of lane 88
# Left lane line 13
# Right lane line 9
#  40%|███████████████████████████████████████████████▋                                                                        | 271/682 [00:07<00:11, 36.84it/s]
# Original number of lane 84
# Left lane line 13
# Right lane line 8
# Original number of lane 68
# Left lane line 9
# Right lane line 8
# Original number of lane 80
# Left lane line 12
# Right lane line 8
# Original number of lane 80
# Left lane line 11
# Right lane line 9
#  40%|████████████████████████████████████████████████▍                                                                       | 275/682 [00:07<00:10, 37.41it/s]
# Original number of lane 84
# Left lane line 12
# Right lane line 9
# Original number of lane 76
# Left lane line 11
# Right lane line 8
# Original number of lane 88
# Left lane line 13
# Right lane line 9
# Original number of lane 120
# Left lane line 20
# Right lane line 10
#  41%|█████████████████████████████████████████████████                                                                       | 279/682 [00:07<00:10, 36.79it/s]
# Original number of lane 140
# Left lane line 22
# Right lane line 13
# Original number of lane 136
# Left lane line 19
# Right lane line 15
# Original number of lane 128
# Left lane line 17
# Right lane line 15
# Original number of lane 120
# Left lane line 14
# Right lane line 16
#  41%|█████████████████████████████████████████████████▊                                                                      | 283/682 [00:07<00:10, 36.66it/s]
# Original number of lane 112
# Left lane line 14
# Right lane line 14
# Original number of lane 116
# Left lane line 14
# Right lane line 15
# Original number of lane 140
# Left lane line 16
# Right lane line 19
# Original number of lane 132
# Left lane line 18
# Right lane line 15
#  42%|██████████████████████████████████████████████████▍                                                                     | 287/682 [00:07<00:10, 36.37it/s]
# Original number of lane 128
# Left lane line 15
# Right lane line 17
# Original number of lane 136
# Left lane line 17
# Right lane line 17
# Original number of lane 148
# Left lane line 18
# Right lane line 19
# Original number of lane 164
# Left lane line 23
# Right lane line 18
#  43%|███████████████████████████████████████████████████▏                                                                    | 291/682 [00:07<00:10, 37.18it/s]
# Original number of lane 176
# Left lane line 22
# Right lane line 22
# Original number of lane 132
# Left lane line 20
# Right lane line 13
# Original number of lane 152
# Left lane line 18
# Right lane line 20
# Original number of lane 88
# Left lane line 13
# Right lane line 9
#  43%|███████████████████████████████████████████████████▉                                                                    | 295/682 [00:07<00:10, 37.55it/s]
# Original number of lane 112
# Left lane line 16
# Right lane line 12
# Original number of lane 112
# Left lane line 16
# Right lane line 12
# Original number of lane 96
# Left lane line 15
# Right lane line 9
# Original number of lane 104
# Left lane line 17
# Right lane line 9
#  44%|████████████████████████████████████████████████████▌                                                                   | 299/682 [00:08<00:10, 38.15it/s]
# Original number of lane 104
# Left lane line 15
# Right lane line 11
# Original number of lane 116
# Left lane line 19
# Right lane line 10
# Original number of lane 132
# Left lane line 19
# Right lane line 14
# Original number of lane 124
# Left lane line 21
# Right lane line 10
#  44%|█████████████████████████████████████████████████████▎                                                                  | 303/682 [00:08<00:09, 38.57it/s]
# Original number of lane 100
# Left lane line 14
# Right lane line 11
# Original number of lane 124
# Left lane line 19
# Right lane line 12
# Original number of lane 100
# Left lane line 13
# Right lane line 12
# Original number of lane 96
# Left lane line 14
# Right lane line 10
#  45%|██████████████████████████████████████████████████████                                                                  | 307/682 [00:08<00:09, 38.10it/s]
# Original number of lane 72
# Left lane line 9
# Right lane line 9
# Original number of lane 76
# Left lane line 8
# Right lane line 11
# Original number of lane 76
# Left lane line 8
# Right lane line 11
# Original number of lane 72
# Left lane line 9
# Right lane line 9
#  46%|██████████████████████████████████████████████████████▋                                                                 | 311/682 [00:08<00:09, 37.88it/s]
# Original number of lane 108
# Left lane line 12
# Right lane line 15
# Original number of lane 104
# Left lane line 12
# Right lane line 14
# Original number of lane 120
# Left lane line 13
# Right lane line 17
# Original number of lane 108
# Left lane line 12
# Right lane line 15
#  46%|███████████████████████████████████████████████████████▍                                                                | 315/682 [00:08<00:09, 37.52it/s]
# Original number of lane 100
# Left lane line 14
# Right lane line 11
# Original number of lane 116
# Left lane line 18
# Right lane line 11
# Original number of lane 148
# Left lane line 18
# Right lane line 19
# Original number of lane 128
# Left lane line 18
# Right lane line 14
#  47%|████████████████████████████████████████████████████████▏                                                               | 319/682 [00:08<00:09, 37.37it/s]
# Original number of lane 88
# Left lane line 10
# Right lane line 12
# Original number of lane 88
# Left lane line 11
# Right lane line 11
# Original number of lane 100
# Left lane line 13
# Right lane line 12
# Original number of lane 84
# Left lane line 13
# Right lane line 8
#  47%|████████████████████████████████████████████████████████▊                                                               | 323/682 [00:08<00:09, 36.66it/s]
# Original number of lane 72
# Left lane line 10
# Right lane line 8
# Original number of lane 88
# Left lane line 14
# Right lane line 8
# Original number of lane 104
# Left lane line 18
# Right lane line 8
# Original number of lane 132
# Left lane line 22
# Right lane line 11
#  48%|█████████████████████████████████████████████████████████▌                                                              | 327/682 [00:08<00:09, 36.97it/s]
# Original number of lane 128
# Left lane line 24
# Right lane line 8
# Original number of lane 128
# Left lane line 25
# Right lane line 7
# Original number of lane 112
# Left lane line 19
# Right lane line 9
# Original number of lane 92
# Left lane line 14
# Right lane line 9
#  49%|██████████████████████████████████████████████████████████▏                                                             | 331/682 [00:08<00:09, 37.10it/s]
# Original number of lane 76
# Left lane line 10
# Right lane line 9
# Original number of lane 84
# Left lane line 15
# Right lane line 6
# Original number of lane 96
# Left lane line 15
# Right lane line 9
# Original number of lane 108
# Left lane line 17
# Right lane line 10
# Original number of lane 100
# Left lane line 16
# Right lane line 9
#  49%|███████████████████████████████████████████████████████████                                                             | 336/682 [00:09<00:09, 37.75it/s]
# Original number of lane 92
# Left lane line 16
# Right lane line 7
# Original number of lane 88
# Left lane line 16
# Right lane line 6
# Original number of lane 104
# Left lane line 20
# Right lane line 6
# Original number of lane 140
# Left lane line 26
# Right lane line 9
# Original number of lane 112
# Left lane line 22
# Right lane line 6
#  50%|████████████████████████████████████████████████████████████                                                            | 341/682 [00:09<00:08, 38.85it/s]
# Original number of lane 148
# Left lane line 25
# Right lane line 12
# Original number of lane 132
# Left lane line 20
# Right lane line 13
# Original number of lane 88
# Left lane line 14
# Right lane line 8
# Original number of lane 76
# Left lane line 12
# Right lane line 7
#  51%|████████████████████████████████████████████████████████████▋                                                           | 345/682 [00:09<00:08, 37.74it/s]
# Original number of lane 88
# Left lane line 15
# Right lane line 7
# Original number of lane 96
# Left lane line 16
# Right lane line 8
# Original number of lane 112
# Left lane line 17
# Right lane line 11
# Original number of lane 104
# Left lane line 16
# Right lane line 10
#  51%|█████████████████████████████████████████████████████████████▍                                                          | 349/682 [00:09<00:08, 37.63it/s]
# Original number of lane 116
# Left lane line 18
# Right lane line 11
# Original number of lane 112
# Left lane line 16
# Right lane line 12
# Original number of lane 120
# Left lane line 20
# Right lane line 10
# Original number of lane 108
# Left lane line 16
# Right lane line 11
#  52%|██████████████████████████████████████████████████████████████                                                          | 353/682 [00:09<00:08, 37.24it/s]
# Original number of lane 132
# Left lane line 21
# Right lane line 12
# Original number of lane 128
# Left lane line 19
# Right lane line 13
# Original number of lane 104
# Left lane line 14
# Right lane line 12
# Original number of lane 108
# Left lane line 13
# Right lane line 14
# Original number of lane 108
# Left lane line 13
# Right lane line 14
#  52%|██████████████████████████████████████████████████████████████▉                                                         | 358/682 [00:09<00:08, 38.56it/s]
# Original number of lane 100
# Left lane line 13
# Right lane line 12
# Original number of lane 116
# Left lane line 15
# Right lane line 14
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 128
# Left lane line 21
# Right lane line 11
#  53%|███████████████████████████████████████████████████████████████▋                                                        | 362/682 [00:09<00:08, 38.42it/s]
# Original number of lane 120
# Left lane line 19
# Right lane line 11
# Original number of lane 120
# Left lane line 19
# Right lane line 11
# Original number of lane 144
# Left lane line 26
# Right lane line 10
# Original number of lane 124
# Left lane line 16
# Right lane line 15
#  54%|████████████████████████████████████████████████████████████████▍                                                       | 366/682 [00:09<00:08, 37.67it/s]
# Original number of lane 120
# Left lane line 17
# Right lane line 13
# Original number of lane 136
# Left lane line 17
# Right lane line 17
# Original number of lane 108
# Left lane line 17
# Right lane line 10
# Original number of lane 120
# Left lane line 15
# Right lane line 15
# Original number of lane 144
# Left lane line 19
# Right lane line 17
#  54%|█████████████████████████████████████████████████████████████████▎                                                      | 371/682 [00:09<00:08, 38.70it/s]
# Original number of lane 152
# Left lane line 18
# Right lane line 20
# Original number of lane 128
# Left lane line 21
# Right lane line 11
# Original number of lane 112
# Left lane line 17
# Right lane line 11
# Original number of lane 112
# Left lane line 19
# Right lane line 9
# Original number of lane 136
# Left lane line 22
# Right lane line 12
#  55%|██████████████████████████████████████████████████████████████████▏                                                     | 376/682 [00:10<00:07, 39.08it/s]
# Original number of lane 156
# Left lane line 28
# Right lane line 11
# Original number of lane 116
# Left lane line 17
# Right lane line 12
# Original number of lane 108
# Left lane line 16
# Right lane line 11
# Original number of lane 92
# Left lane line 10
# Right lane line 13
#  56%|██████████████████████████████████████████████████████████████████▊                                                     | 380/682 [00:10<00:07, 38.89it/s]
# Original number of lane 80
# Left lane line 11
# Right lane line 9
# Original number of lane 88
# Left lane line 12
# Right lane line 10
# Original number of lane 84
# Left lane line 13
# Right lane line 8
# Original number of lane 100
# Left lane line 17
# Right lane line 8
#  56%|███████████████████████████████████████████████████████████████████▌                                                    | 384/682 [00:10<00:07, 39.10it/s]
# Original number of lane 88
# Left lane line 12
# Right lane line 10
# Original number of lane 104
# Left lane line 16
# Right lane line 10
# Original number of lane 104
# Left lane line 18
# Right lane line 8
# Original number of lane 80
# Left lane line 13
# Right lane line 7
#  57%|████████████████████████████████████████████████████████████████████▎                                                   | 388/682 [00:10<00:07, 38.79it/s]
# Original number of lane 96
# Left lane line 16
# Right lane line 8
# Original number of lane 140
# Left lane line 24
# Right lane line 11
# Original number of lane 108
# Left lane line 15
# Right lane line 12
# Original number of lane 100
# Left lane line 13
# Right lane line 12
#  57%|████████████████████████████████████████████████████████████████████▉                                                   | 392/682 [00:10<00:07, 38.03it/s]
# Original number of lane 80
# Left lane line 11
# Right lane line 9
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 88
# Left lane line 15
# Right lane line 7
# Original number of lane 108
# Left lane line 17
# Right lane line 10
# Original number of lane 92
# Left lane line 16
# Right lane line 7
#  58%|█████████████████████████████████████████████████████████████████████▊                                                  | 397/682 [00:10<00:07, 39.15it/s]
# Original number of lane 92
# Left lane line 12
# Right lane line 11
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 116
# Left lane line 20
# Right lane line 9
# Original number of lane 116
# Left lane line 18
# Right lane line 11
#  59%|██████████████████████████████████████████████████████████████████████▌                                                 | 401/682 [00:10<00:07, 38.71it/s]
# Original number of lane 140
# Left lane line 19
# Right lane line 16
# Original number of lane 136
# Left lane line 22
# Right lane line 12
# Original number of lane 108
# Left lane line 17
# Right lane line 10
# Original number of lane 96
# Left lane line 13
# Right lane line 11
#  59%|███████████████████████████████████████████████████████████████████████▎                                                | 405/682 [00:10<00:07, 38.98it/s]
# Original number of lane 80
# Left lane line 11
# Right lane line 9
# Original number of lane 84
# Left lane line 13
# Right lane line 8
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 100
# Left lane line 12
# Right lane line 13
# Original number of lane 108
# Left lane line 16
# Right lane line 11
#  60%|████████████████████████████████████████████████████████████████████████▏                                               | 410/682 [00:10<00:07, 38.82it/s]
# Original number of lane 100
# Left lane line 17
# Right lane line 8
# Original number of lane 96
# Left lane line 12
# Right lane line 12
# Original number of lane 104
# Left lane line 20
# Right lane line 6
# Original number of lane 84
# Left lane line 12
# Right lane line 9
#  61%|████████████████████████████████████████████████████████████████████████▊                                               | 414/682 [00:11<00:06, 38.82it/s]
# Original number of lane 80
# Left lane line 11
# Right lane line 9
# Original number of lane 124
# Left lane line 16
# Right lane line 15
# Original number of lane 76
# Left lane line 11
# Right lane line 8
# Original number of lane 76
# Left lane line 10
# Right lane line 9
#  61%|█████████████████████████████████████████████████████████████████████████▌                                              | 418/682 [00:11<00:06, 38.83it/s]
# Original number of lane 100
# Left lane line 12
# Right lane line 13
# Original number of lane 100
# Left lane line 16
# Right lane line 9
# Original number of lane 112
# Left lane line 18
# Right lane line 10
# Original number of lane 88
# Left lane line 11
# Right lane line 11
#  62%|██████████████████████████████████████████████████████████████████████████▎                                             | 422/682 [00:11<00:06, 38.94it/s]
# Original number of lane 76
# Left lane line 12
# Right lane line 7
# Original number of lane 100
# Left lane line 15
# Right lane line 10
# Original number of lane 68
# Left lane line 11
# Right lane line 6
# Original number of lane 92
# Left lane line 13
# Right lane line 10
#  62%|██████████████████████████████████████████████████████████████████████████▉                                             | 426/682 [00:11<00:06, 38.68it/s]
# Original number of lane 96
# Left lane line 12
# Right lane line 12
# Original number of lane 112
# Left lane line 18
# Right lane line 10
# Original number of lane 68
# Left lane line 8
# Right lane line 9
# Original number of lane 68
# Left lane line 9
# Right lane line 8
#  63%|███████████████████████████████████████████████████████████████████████████▋                                            | 430/682 [00:11<00:06, 38.62it/s]
# Original number of lane 80
# Left lane line 11
# Right lane line 9
# Original number of lane 92
# Left lane line 15
# Right lane line 8
# Original number of lane 92
# Left lane line 11
# Right lane line 12
# Original number of lane 80
# Left lane line 11
# Right lane line 9
# Original number of lane 80
# Left lane line 11
# Right lane line 9
#  64%|████████████████████████████████████████████████████████████████████████████▌                                           | 435/682 [00:11<00:06, 39.02it/s]
# Original number of lane 76
# Left lane line 12
# Right lane line 7
# Original number of lane 92
# Left lane line 14
# Right lane line 9
# Original number of lane 128
# Left lane line 20
# Right lane line 12
# Original number of lane 116
# Left lane line 18
# Right lane line 11
#  64%|█████████████████████████████████████████████████████████████████████████████▏                                          | 439/682 [00:11<00:06, 38.74it/s]
# Original number of lane 108
# Left lane line 18
# Right lane line 9
# Original number of lane 96
# Left lane line 11
# Right lane line 13
# Original number of lane 72
# Left lane line 5
# Right lane line 13
# Original number of lane 68
# Left lane line 9
# Right lane line 8
#  65%|█████████████████████████████████████████████████████████████████████████████▉                                          | 443/682 [00:11<00:06, 38.77it/s]
# Original number of lane 80
# Left lane line 8
# Right lane line 12
# Original number of lane 104
# Left lane line 15
# Right lane line 11
# Original number of lane 104
# Left lane line 14
# Right lane line 12
# Original number of lane 92
# Left lane line 13
# Right lane line 10
#  66%|██████████████████████████████████████████████████████████████████████████████▋                                         | 447/682 [00:11<00:06, 38.79it/s]
# Original number of lane 104
# Left lane line 14
# Right lane line 12
# Original number of lane 96
# Left lane line 12
# Right lane line 12
# Original number of lane 64
# Left lane line 10
# Right lane line 6
# Original number of lane 88
# Left lane line 14
# Right lane line 8
# Original number of lane 100
# Left lane line 16
# Right lane line 9
#  66%|███████████████████████████████████████████████████████████████████████████████▌                                        | 452/682 [00:12<00:05, 39.05it/s]
# Original number of lane 88
# Left lane line 12
# Right lane line 10
# Original number of lane 60
# Left lane line 8
# Right lane line 7
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 48
# Left lane line 4
# Right lane line 8
#  67%|████████████████████████████████████████████████████████████████████████████████▏                                       | 456/682 [00:12<00:05, 38.99it/s]
# Original number of lane 64
# Left lane line 5
# Right lane line 11
# Original number of lane 72
# Left lane line 11
# Right lane line 7
# Original number of lane 96
# Left lane line 12
# Right lane line 12
# Original number of lane 92
# Left lane line 9
# Right lane line 14
# Original number of lane 68
# Left lane line 8
# Right lane line 9
#  68%|█████████████████████████████████████████████████████████████████████████████████                                       | 461/682 [00:12<00:05, 39.57it/s]
# Original number of lane 92
# Left lane line 11
# Right lane line 12
# Original number of lane 92
# Left lane line 11
# Right lane line 12
# Original number of lane 104
# Left lane line 14
# Right lane line 12
# Original number of lane 96
# Left lane line 11
# Right lane line 13
#  68%|█████████████████████████████████████████████████████████████████████████████████▊                                      | 465/682 [00:12<00:05, 39.34it/s]
# Original number of lane 100
# Left lane line 15
# Right lane line 10
# Original number of lane 76
# Left lane line 7
# Right lane line 12
# Original number of lane 72
# Left lane line 8
# Right lane line 10
# Original number of lane 68
# Left lane line 10
# Right lane line 7
# ...
# Original number of lane 124
# Left lane line 12
# Right lane line 19
#  77%|████████████████████████████████████████████████████████████████████████████████████████████▌                           | 526/682 [00:14<00:04, 34.72it/s]
# Original number of lane 92
# Left lane line 11
# Right lane line 12
# Original number of lane 76
# Left lane line 10
# Right lane line 9
# Original number of lane 76
# Left lane line 8
# Right lane line 11
# Original number of lane 64
# Left lane line 6
# Right lane line 10
#  78%|█████████████████████████████████████████████████████████████████████████████████████████████▎                          | 530/682 [00:14<00:04, 34.74it/s]
# Original number of lane 64
# Left lane line 8
# Right lane line 8
# Original number of lane 68
# Left lane line 7
# Right lane line 10
# Original number of lane 60
# Left lane line 7
# Right lane line 8
# Original number of lane 84
# Left lane line 9
# Right lane line 12
#  78%|█████████████████████████████████████████████████████████████████████████████████████████████▉                          | 534/682 [00:14<00:04, 35.21it/s]
# Original number of lane 84
# Left lane line 10
# Right lane line 11
# Original number of lane 92
# Left lane line 11
# Right lane line 12
# Original number of lane 124
# Left lane line 17
# Right lane line 14
# Original number of lane 92
# Left lane line 13
# Right lane line 10
#  79%|██████████████████████████████████████████████████████████████████████████████████████████████▋                         | 538/682 [00:14<00:03, 36.13it/s]
# Original number of lane 88
# Left lane line 10
# Right lane line 12
# Original number of lane 88
# Left lane line 14
# Right lane line 8
# Original number of lane 52
# Left lane line 5
# Right lane line 8
# Original number of lane 108
# Left lane line 11
# Right lane line 16
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████▎                        | 542/682 [00:14<00:03, 36.80it/s]
# Original number of lane 60
# Left lane line 8
# Right lane line 7
# Original number of lane 64
# Left lane line 8
# Right lane line 8
# Original number of lane 60
# Left lane line 7
# Right lane line 8
# Original number of lane 56
# Left lane line 6
# Right lane line 8
# Original number of lane 72
# Left lane line 9
# Right lane line 9
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████▏                       | 547/682 [00:14<00:03, 38.13it/s]
# Original number of lane 72
# Left lane line 7
# Right lane line 11
# Original number of lane 88
# Left lane line 10
# Right lane line 12
# Original number of lane 84
# Left lane line 11
# Right lane line 10
# Original number of lane 80
# Left lane line 9
# Right lane line 11
# Original number of lane 96
# Left lane line 12
# Right lane line 12
#  81%|█████████████████████████████████████████████████████████████████████████████████████████████████▏                      | 552/682 [00:14<00:03, 38.59it/s]
# Original number of lane 52
# Left lane line 4
# Right lane line 9
# Original number of lane 56
# Left lane line 5
# Right lane line 9
# Original number of lane 56
# Left lane line 6
# Right lane line 8
# Original number of lane 60
# Left lane line 5
# Right lane line 10
# Original number of lane 68
# Left lane line 9
# Right lane line 8
#  82%|██████████████████████████████████████████████████████████████████████████████████████████████████                      | 557/682 [00:14<00:03, 38.73it/s]
# Original number of lane 52
# Left lane line 4
# Right lane line 9
# Original number of lane 72
# Left lane line 6
# Right lane line 12
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 84
# Left lane line 6
# Right lane line 15
#  82%|██████████████████████████████████████████████████████████████████████████████████████████████████▋                     | 561/682 [00:14<00:03, 38.76it/s]
# Original number of lane 88
# Left lane line 7
# Right lane line 15
# Original number of lane 72
# Left lane line 7
# Right lane line 11
# Original number of lane 80
# Left lane line 5
# Right lane line 15
# Original number of lane 64
# Left lane line 5
# Right lane line 11
#  83%|███████████████████████████████████████████████████████████████████████████████████████████████████▍                    | 565/682 [00:15<00:03, 37.69it/s]
# Original number of lane 52
# Left lane line 2
# Right lane line 11
# Original number of lane 52
# Left lane line 3
# Right lane line 10
# Original number of lane 60
# Left lane line 3
# Right lane line 12
# Original number of lane 60
# Left lane line 4
# Right lane line 11
#  83%|████████████████████████████████████████████████████████████████████████████████████████████████████                    | 569/682 [00:15<00:03, 36.07it/s]
# Original number of lane 60
# Left lane line 4
# Right lane line 11
# Original number of lane 56
# Left lane line 4
# Right lane line 10
# Original number of lane 76
# Left lane line 7
# Right lane line 12
# Original number of lane 92
# Left lane line 8
# Right lane line 15
# Original number of lane 72
# Left lane line 8
# Right lane line 10
#  84%|████████████████████████████████████████████████████████████████████████████████████████████████████▉                   | 574/682 [00:15<00:02, 37.16it/s]
# Original number of lane 96
# Left lane line 11
# Right lane line 13
# Original number of lane 80
# Left lane line 8
# Right lane line 12
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 36
# Left lane line 2
# Right lane line 7
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████▋                  | 578/682 [00:15<00:02, 35.93it/s]
# Original number of lane 44
# Left lane line 1
# Right lane line 10
# Original number of lane 40
# Left lane line 2
# Right lane line 8
# Original number of lane 60
# Left lane line 4
# Right lane line 11
# Original number of lane 72
# Left lane line 5
# Right lane line 13
#  85%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 582/682 [00:15<00:02, 36.85it/s]
# Original number of lane 60
# Left lane line 4
# Right lane line 11
# Original number of lane 56
# Left lane line 3
# Right lane line 11
# Original number of lane 80
# Left lane line 6
# Right lane line 14
# Original number of lane 68
# Left lane line 6
# Right lane line 11
#  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████                 | 586/682 [00:15<00:02, 36.91it/s]
# Original number of lane 88
# Left lane line 7
# Right lane line 15
# Original number of lane 76
# Left lane line 6
# Right lane line 13
# Original number of lane 80
# Left lane line 7
# Right lane line 13
# Original number of lane 56
# Left lane line 2
# Right lane line 12
# Original number of lane 60
# Left lane line 5
# Right lane line 10
#  87%|███████████████████████████████████████████████████████████████████████████████████████████████████████▉                | 591/682 [00:15<00:02, 37.78it/s]
# Original number of lane 76
# Left lane line 6
# Right lane line 13
# Original number of lane 100
# Left lane line 8
# Right lane line 17
# Original number of lane 84
# Left lane line 9
# Right lane line 12
# Original number of lane 72
# Left lane line 8
# Right lane line 10
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████▋               | 595/682 [00:15<00:02, 37.24it/s]
# Original number of lane 100
# Left lane line 11
# Right lane line 14
# Original number of lane 92
# Left lane line 12
# Right lane line 11
# Original number of lane 116
# Left lane line 17
# Right lane line 12
# Original number of lane 104
# Left lane line 13
# Right lane line 13
#  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▍              | 599/682 [00:15<00:02, 37.92it/s]
# Original number of lane 112
# Left lane line 12
# Right lane line 16
# Original number of lane 92
# Left lane line 10
# Right lane line 13
# Original number of lane 76
# Left lane line 7
# Right lane line 12
# Original number of lane 52
# Left lane line 3
# Right lane line 10
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████              | 603/682 [00:16<00:02, 37.65it/s]
# Original number of lane 64
# Left lane line 1
# Right lane line 15
# Original number of lane 56
# Left lane line 2
# Right lane line 12
# Original number of lane 68
# Left lane line 5
# Right lane line 12
# Original number of lane 68
# Left lane line 4
# Right lane line 13
#  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▊             | 607/682 [00:16<00:01, 38.22it/s]
# Original number of lane 88
# Left lane line 9
# Right lane line 13
# Original number of lane 72
# Left lane line 6
# Right lane line 12
# Original number of lane 68
# Left lane line 7
# Right lane line 10
# Original number of lane 88
# Left lane line 10
# Right lane line 12
#  90%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▌            | 611/682 [00:16<00:01, 38.40it/s]
# Original number of lane 92
# Left lane line 10
# Right lane line 13
# Original number of lane 84
# Left lane line 8
# Right lane line 13
# Original number of lane 88
# Left lane line 12
# Right lane line 10
# Original number of lane 68
# Left lane line 5
# Right lane line 12
#  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▏           | 615/682 [00:16<00:01, 38.42it/s]
# Original number of lane 56
# Left lane line 4
# Right lane line 10
# Original number of lane 60
# Left lane line 4
# Right lane line 11
# Original number of lane 84
# Left lane line 7
# Right lane line 14
# Original number of lane 72
# Left lane line 5
# Right lane line 13
#  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▉           | 619/682 [00:16<00:01, 38.77it/s]
# Original number of lane 96
# Left lane line 8
# Right lane line 16
# Original number of lane 84
# Left lane line 7
# Right lane line 14
# Original number of lane 72
# Left lane line 7
# Right lane line 11
# Original number of lane 68
# Left lane line 5
# Right lane line 12
#  91%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▌          | 623/682 [00:16<00:01, 38.01it/s]
# Original number of lane 68
# Left lane line 6
# Right lane line 11
# Original number of lane 76
# Left lane line 3
# Right lane line 16
# Original number of lane 72
# Left lane line 6
# Right lane line 12
# Original number of lane 44
# Left lane line 3
# Right lane line 8
#  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▎         | 627/682 [00:16<00:01, 38.48it/s]
# Original number of lane 40
# Left lane line 3
# Right lane line 7
# Original number of lane 48
# Left lane line 4
# Right lane line 8
# Original number of lane 68
# Left lane line 5
# Right lane line 12
# Original number of lane 64
# Left lane line 9
# Right lane line 7
# Original number of lane 76
# Left lane line 8
# Right lane line 11
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 632/682 [00:16<00:01, 39.20it/s]
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 56
# Left lane line 8
# Right lane line 6
# Original number of lane 60
# Left lane line 9
# Right lane line 6
# Original number of lane 76
# Left lane line 10
# Right lane line 9
# Original number of lane 80
# Left lane line 11
# Right lane line 9
#  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████        | 637/682 [00:16<00:01, 39.62it/s]
# Original number of lane 76
# Left lane line 8
# Right lane line 11
# Original number of lane 76
# Left lane line 9
# Right lane line 10
# Original number of lane 60
# Left lane line 6
# Right lane line 9
# Original number of lane 48
# Left lane line 5
# Right lane line 7
#  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊       | 641/682 [00:17<00:01, 39.73it/s]
# Original number of lane 60
# Left lane line 7
# Right lane line 8
# Original number of lane 68
# Left lane line 11
# Right lane line 6
# Original number of lane 56
# Left lane line 6
# Right lane line 8
# Original number of lane 52
# Left lane line 5
# Right lane line 8
#  95%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍      | 645/682 [00:17<00:00, 39.23it/s]
# Original number of lane 56
# Left lane line 5
# Right lane line 9
# Original number of lane 64
# Left lane line 7
# Right lane line 9
# Original number of lane 88
# Left lane line 13
# Right lane line 9
# Original number of lane 72
# Left lane line 11
# Right lane line 7
#  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏     | 649/682 [00:17<00:00, 39.46it/s]
# Original number of lane 80
# Left lane line 9
# Right lane line 11
# Original number of lane 72
# Left lane line 9
# Right lane line 9
# Original number of lane 44
# Left lane line 5
# Right lane line 6
# Original number of lane 56
# Left lane line 6
# Right lane line 8
#  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉     | 653/682 [00:17<00:00, 38.36it/s]
# Original number of lane 56
# Left lane line 5
# Right lane line 9
# Original number of lane 64
# Left lane line 6
# Right lane line 10
# Original number of lane 60
# Left lane line 5
# Right lane line 10
# Original number of lane 40
# Left lane line 4
# Right lane line 6
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 657/682 [00:17<00:00, 38.73it/s]
# Original number of lane 48
# Left lane line 6
# Right lane line 6
# Original number of lane 64
# Left lane line 8
# Right lane line 8
# Original number of lane 56
# Left lane line 7
# Right lane line 7
# Original number of lane 92
# Left lane line 11
# Right lane line 12
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 661/682 [00:17<00:00, 38.87it/s]
# Original number of lane 80
# Left lane line 11
# Right lane line 9
# Original number of lane 88
# Left lane line 10
# Right lane line 12
# Original number of lane 56
# Left lane line 6
# Right lane line 8
# Original number of lane 36
# Left lane line 1
# Right lane line 8
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████   | 665/682 [00:17<00:00, 38.64it/s]
# Original number of lane 44
# Left lane line 4
# Right lane line 7
# Original number of lane 52
# Left lane line 4
# Right lane line 9
# Original number of lane 56
# Left lane line 7
# Right lane line 7
# Original number of lane 68
# Left lane line 5
# Right lane line 12
# Original number of lane 64
# Left lane line 8
# Right lane line 8
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉  | 670/682 [00:17<00:00, 39.04it/s]
# Original number of lane 76
# Left lane line 9
# Right lane line 10
# Original number of lane 72
# Left lane line 9
# Right lane line 9
# Original number of lane 112
# Left lane line 10
# Right lane line 18
# Original number of lane 96
# Left lane line 13
# Right lane line 11
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 674/682 [00:17<00:00, 39.32it/s]
# Original number of lane 108
# Left lane line 13
# Right lane line 14
# Original number of lane 104
# Left lane line 11
# Right lane line 15
# Original number of lane 80
# Left lane line 7
# Right lane line 13
# Original number of lane 60
# Left lane line 7
# Right lane line 8
# Original number of lane 68
# Left lane line 8
# Right lane line 9
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍| 679/682 [00:18<00:00, 40.19it/s]
# Original number of lane 76
# Left lane line 10
# Right lane line 9
# Original number of lane 92
# Left lane line 13
# Right lane line 10
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊| 681/682 [00:18<00:00, 37.65it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: solidYellowLeft.mp4
#
# Wall time: 18.5 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="solidYellowLeft.mp4">
# </video>

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'challenge.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip3 = VideoFileClip('test_videos/challenge.mp4').subclip(0,5)
clip3 = VideoFileClip('test_videos/challenge.mp4')
challenge_clip = clip3.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False);
# Out:
# Original number of lane 424
# Left lane line 33
# Right lane line 73
# [MoviePy] >>>> Building video challenge.mp4
# [MoviePy] Writing video challenge.mp4
#   0%|                                                                                                                                  | 0/251 [00:00<?, ?it/s]
# Original number of lane 424
# Left lane line 33
# Right lane line 73
# Original number of lane 452
# Left lane line 34
# Right lane line 79
#   1%|▉                                                                                                                         | 2/251 [00:00<00:15, 15.62it/s]
# Original number of lane 416
# Left lane line 35
# Right lane line 69
# Original number of lane 484
# Left lane line 33
# Right lane line 88
# Original number of lane 400
# Left lane line 25
# Right lane line 75
#   2%|██▍                                                                                                                       | 5/251 [00:00<00:13, 17.64it/s]
# Original number of lane 536
# Left lane line 47
# Right lane line 87
# Original number of lane 492
# Left lane line 38
# Right lane line 85
# Original number of lane 468
# Left lane line 39
# Right lane line 78
#   3%|███▉                                                                                                                      | 8/251 [00:00<00:14, 17.10it/s]
# Original number of lane 504
# Left lane line 38
# Right lane line 88
# Original number of lane 452
# Left lane line 35
# Right lane line 78
# Original number of lane 488
# Left lane line 37
# Right lane line 85
#   4%|█████▎                                                                                                                   | 11/251 [00:00<00:12, 18.64it/s]
# Original number of lane 492
# Left lane line 28
# Right lane line 95
# Original number of lane 444
# Left lane line 51
# Right lane line 60
# Original number of lane 444
# Left lane line 41
# Right lane line 70
#   6%|██████▋                                                                                                                  | 14/251 [00:00<00:11, 20.26it/s]
# Original number of lane 468
# Left lane line 40
# Right lane line 77
# Original number of lane 452
# Left lane line 35
# Right lane line 78
# Original number of lane 492
# Left lane line 38
# Right lane line 85
#   7%|████████▏                                                                                                                | 17/251 [00:00<00:10, 21.44it/s]
# Original number of lane 480
# Left lane line 46
# Right lane line 74
# Original number of lane 584
# Left lane line 53
# Right lane line 93
# Original number of lane 488
# Left lane line 44
# Right lane line 78
#   8%|█████████▋                                                                                                               | 20/251 [00:00<00:10, 22.15it/s]
# Original number of lane 504
# Left lane line 45
# Right lane line 81
# Original number of lane 548
# Left lane line 54
# Right lane line 83
# Original number of lane 516
# Left lane line 46
# Right lane line 83
#   9%|███████████                                                                                                              | 23/251 [00:01<00:10, 22.72it/s]
# Original number of lane 524
# Left lane line 58
# Right lane line 73
# Original number of lane 532
# Left lane line 54
# Right lane line 79
# Original number of lane 568
# Left lane line 60
# Right lane line 82
#  10%|████████████▌                                                                                                            | 26/251 [00:01<00:10, 20.83it/s]
# Original number of lane 572
# Left lane line 56
# Right lane line 87
# Original number of lane 596
# Left lane line 58
# Right lane line 91
# Original number of lane 536
# Left lane line 46
# Right lane line 88
#  12%|█████████████▉                                                                                                           | 29/251 [00:01<00:11, 19.88it/s]
# Original number of lane 492
# Left lane line 35
# Right lane line 88
# Original number of lane 536
# Left lane line 58
# Right lane line 76
# Original number of lane 496
# Left lane line 56
# Right lane line 68
#  13%|███████████████▍                                                                                                         | 32/251 [00:01<00:11, 19.60it/s]
# Original number of lane 568
# Left lane line 51
# Right lane line 91
# Original number of lane 620
# Left lane line 59
# Right lane line 96
# Original number of lane 628
# Left lane line 47
# Right lane line 110
#  14%|████████████████▊                                                                                                        | 35/251 [00:01<00:10, 20.12it/s]
# Original number of lane 600
# Left lane line 48
# Right lane line 102
# Original number of lane 608
# Left lane line 59
# Right lane line 93
# Original number of lane 616
# Left lane line 69
# Right lane line 85
#  15%|██████████████████▎                                                                                                      | 38/251 [00:01<00:11, 19.16it/s]
# Original number of lane 640
# Left lane line 54
# Right lane line 106
# Original number of lane 628
# Left lane line 50
# Right lane line 107
# Original number of lane 612
# Left lane line 70
# Right lane line 83
#  16%|███████████████████▊                                                                                                     | 41/251 [00:01<00:10, 20.65it/s]
# Original number of lane 744
# Left lane line 78
# Right lane line 108
# Original number of lane 884
# Left lane line 100
# Right lane line 121
# Original number of lane 764
# Left lane line 106
# Right lane line 85
#  18%|█████████████████████▏                                                                                                   | 44/251 [00:02<00:09, 21.14it/s]
# Original number of lane 876
# Left lane line 107
# Right lane line 112
# Original number of lane 904
# Left lane line 118
# Right lane line 108
# Original number of lane 1024
# Left lane line 111
# Right lane line 145
#  19%|██████████████████████▋                                                                                                  | 47/251 [00:02<00:09, 21.27it/s]
# Original number of lane 900
# Left lane line 112
# Right lane line 113
# Original number of lane 988
# Left lane line 106
# Right lane line 141
# Original number of lane 1016
# Left lane line 135
# Right lane line 119
#  20%|████████████████████████                                                                                                 | 50/251 [00:02<00:09, 21.83it/s]
# Original number of lane 1100
# Left lane line 129
# Right lane line 146
# Original number of lane 1004
# Left lane line 121
# Right lane line 130
# Original number of lane 1112
# Left lane line 125
# Right lane line 153
#  21%|█████████████████████████▌                                                                                               | 53/251 [00:02<00:09, 21.52it/s]
# Original number of lane 1172
# Left lane line 139
# Right lane line 154
# Original number of lane 1252
# Left lane line 146
# Right lane line 167
# Original number of lane 1296
# Left lane line 188
# Right lane line 136
#  22%|██████████████████████████▉                                                                                              | 56/251 [00:02<00:09, 21.49it/s]
# Original number of lane 1432
# Left lane line 204
# Right lane line 154
# Original number of lane 1356
# Left lane line 181
# Right lane line 158
# Original number of lane 1296
# Left lane line 155
# Right lane line 169
#  24%|████████████████████████████▍                                                                                            | 59/251 [00:02<00:09, 21.11it/s]
# Original number of lane 1356
# Left lane line 158
# Right lane line 181
# Original number of lane 1304
# Left lane line 140
# Right lane line 186
# Original number of lane 1436
# Left lane line 198
# Right lane line 161
#  25%|█████████████████████████████▉                                                                                           | 62/251 [00:02<00:08, 21.25it/s]
# Original number of lane 1300
# Left lane line 135
# Right lane line 190
# Original number of lane 1600
# Left lane line 165
# Right lane line 235
# Original number of lane 1544
# Left lane line 143
# Right lane line 243
#  26%|███████████████████████████████▎                                                                                         | 65/251 [00:03<00:09, 19.44it/s]
# Original number of lane 1604
# Left lane line 139
# Right lane line 262
# Original number of lane 1628
# Left lane line 162
# Right lane line 245
#  27%|████████████████████████████████▎                                                                                        | 67/251 [00:03<00:09, 19.43it/s]
# Original number of lane 1700
# Left lane line 128
# Right lane line 297
# Original number of lane 1600
# Left lane line 138
# Right lane line 262
#  27%|█████████████████████████████████▎                                                                                       | 69/251 [00:03<00:10, 18.01it/s]
# Original number of lane 1748
# Left lane line 129
# Right lane line 308
# Original number of lane 1708
# Left lane line 85
# Right lane line 342
# Original number of lane 1636
# Left lane line 117
# Right lane line 292
#  29%|██████████████████████████████████▋                                                                                      | 72/251 [00:03<00:09, 18.77it/s]
# Original number of lane 1608
# Left lane line 100
# Right lane line 302
# Original number of lane 1504
# Left lane line 72
# Right lane line 304
#  29%|███████████████████████████████████▋                                                                                     | 74/251 [00:03<00:09, 18.70it/s]
# Original number of lane 1480
# Left lane line 101
# Right lane line 269
# Original number of lane 1276
# Left lane line 75
# Right lane line 244
#  30%|████████████████████████████████████▋                                                                                    | 76/251 [00:03<00:09, 18.70it/s]
# Original number of lane 1308
# Left lane line 76
# Right lane line 251
# Original number of lane 1508
# Left lane line 85
# Right lane line 292
# Original number of lane 1500
# Left lane line 58
# Right lane line 317
#  31%|██████████████████████████████████████                                                                                   | 79/251 [00:03<00:08, 19.82it/s]
# Original number of lane 1508
# Left lane line 55
# Right lane line 322
# Original number of lane 1520
# Left lane line 44
# Right lane line 336
# Original number of lane 1536
# Left lane line 35
# Right lane line 349
#  33%|███████████████████████████████████████▌                                                                                 | 82/251 [00:04<00:08, 19.84it/s]
# Original number of lane 1520
# Left lane line 26
# Right lane line 354
# Original number of lane 1736
# Left lane line 39
# Right lane line 395
# Original number of lane 1516
# Left lane line 44
# Right lane line 335
#  34%|████████████████████████████████████████▉                                                                                | 85/251 [00:04<00:08, 18.70it/s]
# Original number of lane 1468
# Left lane line 29
# Right lane line 338
# Original number of lane 1488
# Left lane line 37
# Right lane line 335
#  35%|█████████████████████████████████████████▉                                                                               | 87/251 [00:04<00:09, 17.84it/s]
# Original number of lane 1588
# Left lane line 35
# Right lane line 362
# Original number of lane 1532
# Left lane line 39
# Right lane line 344
#  35%|██████████████████████████████████████████▉                                                                              | 89/251 [00:04<00:09, 17.43it/s]
# Original number of lane 1536
# Left lane line 35
# Right lane line 349
# Original number of lane 1388
# Left lane line 28
# Right lane line 319
#  36%|███████████████████████████████████████████▊                                                                             | 91/251 [00:04<00:09, 16.72it/s]
# Original number of lane 1616
# Left lane line 37
# Right lane line 367
# Original number of lane 1580
# Left lane line 24
# Right lane line 371
#  37%|████████████████████████████████████████████▊                                                                            | 93/251 [00:04<00:09, 17.40it/s]
# Original number of lane 1480
# Left lane line 23
# Right lane line 347
# Original number of lane 1628
# Left lane line 34
# Right lane line 373
#  38%|█████████████████████████████████████████████▊                                                                           | 95/251 [00:04<00:08, 17.96it/s]
# Original number of lane 1620
# Left lane line 23
# Right lane line 382
# Original number of lane 1436
# Left lane line 32
# Right lane line 327
#  39%|██████████████████████████████████████████████▊                                                                          | 97/251 [00:04<00:08, 18.22it/s]
# Original number of lane 1500
# Left lane line 44
# Right lane line 331
# Original number of lane 1332
# Left lane line 40
# Right lane line 293
#  39%|███████████████████████████████████████████████▋                                                                         | 99/251 [00:05<00:08, 17.13it/s]
# Original number of lane 1532
# Left lane line 44
# Right lane line 339
# Original number of lane 1436
# Left lane line 42
# Right lane line 317
# Original number of lane 1596
# Left lane line 42
# Right lane line 357
#  41%|████████████████████████████████████████████████▊                                                                       | 102/251 [00:05<00:08, 18.43it/s]
# Original number of lane 1664
# Left lane line 61
# Right lane line 355
# Original number of lane 1696
# Left lane line 44
# Right lane line 380
#  41%|█████████████████████████████████████████████████▋                                                                      | 104/251 [00:05<00:07, 18.51it/s]
# Original number of lane 1284
# Left lane line 54
# Right lane line 267
# Original number of lane 1416
# Left lane line 38
# Right lane line 316
# Original number of lane 1480
# Left lane line 40
# Right lane line 330
#  43%|███████████████████████████████████████████████████▏                                                                    | 107/251 [00:05<00:07, 20.53it/s]
# Original number of lane 1148
# Left lane line 39
# Right lane line 248
# Original number of lane 1312
# Left lane line 29
# Right lane line 299
# Original number of lane 1200
# Left lane line 43
# Right lane line 257
#  44%|████████████████████████████████████████████████████▌                                                                   | 110/251 [00:05<00:06, 21.69it/s]
# Original number of lane 1244
# Left lane line 49
# Right lane line 262
# Original number of lane 1432
# Left lane line 66
# Right lane line 292
# Original number of lane 1200
# Left lane line 52
# Right lane line 248
#  45%|██████████████████████████████████████████████████████                                                                  | 113/251 [00:05<00:06, 22.79it/s]
# Original number of lane 1216
# Left lane line 42
# Right lane line 262
# Original number of lane 1200
# Left lane line 40
# Right lane line 260
# Original number of lane 1196
# Left lane line 36
# Right lane line 263
#  46%|███████████████████████████████████████████████████████▍                                                                | 116/251 [00:05<00:05, 23.58it/s]
# Original number of lane 1196
# Left lane line 74
# Right lane line 225
# Original number of lane 1120
# Left lane line 68
# Right lane line 212
# Original number of lane 1252
# Left lane line 56
# Right lane line 257
#  47%|████████████████████████████████████████████████████████▉                                                               | 119/251 [00:05<00:05, 23.82it/s]
# Original number of lane 1348
# Left lane line 54
# Right lane line 283
# Original number of lane 1276
# Left lane line 58
# Right lane line 261
# Original number of lane 1272
# Left lane line 47
# Right lane line 271
#  49%|██████████████████████████████████████████████████████████▎                                                             | 122/251 [00:05<00:05, 24.58it/s]
# Original number of lane 1264
# Left lane line 55
# Right lane line 261
# Original number of lane 1268
# Left lane line 58
# Right lane line 259
# Original number of lane 1292
# Left lane line 53
# Right lane line 270
#  50%|███████████████████████████████████████████████████████████▊                                                            | 125/251 [00:06<00:05, 24.58it/s]
# Original number of lane 1372
# Left lane line 55
# Right lane line 288
# Original number of lane 1292
# Left lane line 55
# Right lane line 268
# Original number of lane 1256
# Left lane line 24
# Right lane line 290
#  51%|█████████████████████████████████████████████████████████████▏                                                          | 128/251 [00:06<00:05, 24.11it/s]
# Original number of lane 1284
# Left lane line 30
# Right lane line 291
# Original number of lane 1212
# Left lane line 21
# Right lane line 282
# Original number of lane 1052
# Left lane line 35
# Right lane line 228
#  52%|██████████████████████████████████████████████████████████████▋                                                         | 131/251 [00:06<00:04, 24.25it/s]
# Original number of lane 1100
# Left lane line 36
# Right lane line 239
# Original number of lane 988
# Left lane line 24
# Right lane line 223
# Original number of lane 1308
# Left lane line 40
# Right lane line 287
#  53%|████████████████████████████████████████████████████████████████                                                        | 134/251 [00:06<00:04, 24.65it/s]
# Original number of lane 1208
# Left lane line 34
# Right lane line 268
# Original number of lane 1232
# Left lane line 30
# Right lane line 278
# Original number of lane 1384
# Left lane line 42
# Right lane line 304
#  55%|█████████████████████████████████████████████████████████████████▍                                                      | 137/251 [00:06<00:04, 24.88it/s]
# Original number of lane 1352
# Left lane line 24
# Right lane line 314
# Original number of lane 1360
# Left lane line 37
# Right lane line 303
# Original number of lane 1400
# Left lane line 42
# Right lane line 308
#  56%|██████████████████████████████████████████████████████████████████▉                                                     | 140/251 [00:06<00:04, 25.10it/s]
# Original number of lane 1296
# Left lane line 50
# Right lane line 274
# Original number of lane 1180
# Left lane line 26
# Right lane line 269
# Original number of lane 1240
# Left lane line 40
# Right lane line 270
#  57%|████████████████████████████████████████████████████████████████████▎                                                   | 143/251 [00:06<00:04, 24.52it/s]
# Original number of lane 1076
# Left lane line 25
# Right lane line 244
# Original number of lane 860
# Left lane line 18
# Right lane line 197
# Original number of lane 712
# Left lane line 22
# Right lane line 156
#  58%|█████████████████████████████████████████████████████████████████████▊                                                  | 146/251 [00:06<00:04, 24.97it/s]
# Original number of lane 664
# Left lane line 11
# Right lane line 155
# Original number of lane 600
# Left lane line 11
# Right lane line 139
# Original number of lane 692
# Left lane line 17
# Right lane line 156
#  59%|███████████████████████████████████████████████████████████████████████▏                                                | 149/251 [00:07<00:04, 25.29it/s]
# Original number of lane 644
# Left lane line 28
# Right lane line 133
# Original number of lane 624
# Left lane line 20
# Right lane line 136
# Original number of lane 564
# Left lane line 16
# Right lane line 125
#  61%|████████████████████████████████████████████████████████████████████████▋                                               | 152/251 [00:07<00:03, 25.99it/s]
# Original number of lane 560
# Left lane line 12
# Right lane line 128
# Original number of lane 560
# Left lane line 15
# Right lane line 125
# Original number of lane 580
# Left lane line 13
# Right lane line 132
#  62%|██████████████████████████████████████████████████████████████████████████                                              | 155/251 [00:07<00:03, 26.02it/s]
# Original number of lane 628
# Left lane line 17
# Right lane line 140
# Original number of lane 656
# Left lane line 14
# Right lane line 150
# Original number of lane 568
# Left lane line 13
# Right lane line 129
#  63%|███████████████████████████████████████████████████████████████████████████▌                                            | 158/251 [00:07<00:03, 23.36it/s]
# Original number of lane 572
# Left lane line 14
# Right lane line 129
# Original number of lane 492
# Left lane line 12
# Right lane line 111
# Original number of lane 440
# Left lane line 16
# Right lane line 94
#  64%|████████████████████████████████████████████████████████████████████████████▉                                           | 161/251 [00:07<00:04, 22.19it/s]
# Original number of lane 516
# Left lane line 16
# Right lane line 113
# Original number of lane 444
# Left lane line 18
# Right lane line 93
# Original number of lane 500
# Left lane line 12
# Right lane line 113
#  65%|██████████████████████████████████████████████████████████████████████████████▍                                         | 164/251 [00:07<00:03, 22.76it/s]
# Original number of lane 524
# Left lane line 16
# Right lane line 115
# Original number of lane 600
# Left lane line 14
# Right lane line 136
# Original number of lane 396
# Left lane line 15
# Right lane line 84
#  67%|███████████████████████████████████████████████████████████████████████████████▊                                        | 167/251 [00:07<00:03, 23.28it/s]
# Original number of lane 504
# Left lane line 20
# Right lane line 106
# Original number of lane 528
# Left lane line 10
# Right lane line 122
# Original number of lane 592
# Left lane line 20
# Right lane line 128
#  68%|█████████████████████████████████████████████████████████████████████████████████▎                                      | 170/251 [00:07<00:03, 22.90it/s]
# Original number of lane 672
# Left lane line 25
# Right lane line 143
# Original number of lane 608
# Left lane line 21
# Right lane line 131
# Original number of lane 544
# Left lane line 14
# Right lane line 122
#  69%|██████████████████████████████████████████████████████████████████████████████████▋                                     | 173/251 [00:08<00:03, 20.38it/s]
# Original number of lane 672
# Left lane line 26
# Right lane line 142
# Original number of lane 540
# Left lane line 28
# Right lane line 107
# Original number of lane 548
# Left lane line 19
# Right lane line 118
#  70%|████████████████████████████████████████████████████████████████████████████████████▏                                   | 176/251 [00:08<00:04, 18.37it/s]
# Original number of lane 476
# Left lane line 19
# Right lane line 100
# Original number of lane 592
# Left lane line 16
# Right lane line 132
#  71%|█████████████████████████████████████████████████████████████████████████████████████                                   | 178/251 [00:08<00:04, 17.22it/s]
# Original number of lane 512
# Left lane line 31
# Right lane line 97
# Original number of lane 452
# Left lane line 31
# Right lane line 82
#  72%|██████████████████████████████████████████████████████████████████████████████████████                                  | 180/251 [00:08<00:04, 17.36it/s]
# Original number of lane 556
# Left lane line 19
# Right lane line 120
# Original number of lane 544
# Left lane line 27
# Right lane line 109
# Original number of lane 580
# Left lane line 28
# Right lane line 117
#  73%|███████████████████████████████████████████████████████████████████████████████████████▍                                | 183/251 [00:08<00:03, 18.31it/s]
# Original number of lane 584
# Left lane line 29
# Right lane line 117
# Original number of lane 628
# Left lane line 28
# Right lane line 129
#  74%|████████████████████████████████████████████████████████████████████████████████████████▍                               | 185/251 [00:08<00:03, 17.78it/s]
# Original number of lane 632
# Left lane line 34
# Right lane line 124
# Original number of lane 652
# Left lane line 25
# Right lane line 138
# Original number of lane 584
# Left lane line 23
# Right lane line 123
#  75%|█████████████████████████████████████████████████████████████████████████████████████████▉                              | 188/251 [00:08<00:03, 18.67it/s]
# Original number of lane 628
# Left lane line 18
# Right lane line 139
# Original number of lane 504
# Left lane line 22
# Right lane line 104
# Original number of lane 532
# Left lane line 20
# Right lane line 113
#  76%|███████████████████████████████████████████████████████████████████████████████████████████▎                            | 191/251 [00:09<00:03, 19.88it/s]
# Original number of lane 572
# Left lane line 26
# Right lane line 117
# Original number of lane 536
# Left lane line 18
# Right lane line 116
# Original number of lane 652
# Left lane line 28
# Right lane line 135
#  77%|████████████████████████████████████████████████████████████████████████████████████████████▋                           | 194/251 [00:09<00:02, 22.02it/s]
# Original number of lane 640
# Left lane line 47
# Right lane line 113
# Original number of lane 536
# Left lane line 21
# Right lane line 113
# Original number of lane 532
# Left lane line 22
# Right lane line 111
#  78%|██████████████████████████████████████████████████████████████████████████████████████████████▏                         | 197/251 [00:09<00:02, 23.43it/s]
# Original number of lane 508
# Left lane line 17
# Right lane line 110
# Original number of lane 592
# Left lane line 26
# Right lane line 122
# Original number of lane 628
# Left lane line 15
# Right lane line 142
#  80%|███████████████████████████████████████████████████████████████████████████████████████████████▌                        | 200/251 [00:09<00:02, 24.64it/s]
# Original number of lane 536
# Left lane line 21
# Right lane line 113
# Original number of lane 488
# Left lane line 15
# Right lane line 107
# Original number of lane 616
# Left lane line 23
# Right lane line 131
#  81%|█████████████████████████████████████████████████████████████████████████████████████████████████                       | 203/251 [00:09<00:01, 25.00it/s]
# Original number of lane 484
# Left lane line 11
# Right lane line 110
# Original number of lane 504
# Left lane line 16
# Right lane line 110
# Original number of lane 456
# Left lane line 15
# Right lane line 99
#  82%|██████████████████████████████████████████████████████████████████████████████████████████████████▍                     | 206/251 [00:09<00:01, 25.57it/s]
# Original number of lane 544
# Left lane line 16
# Right lane line 120
# Original number of lane 548
# Left lane line 24
# Right lane line 113
# Original number of lane 592
# Left lane line 21
# Right lane line 127
#  83%|███████████████████████████████████████████████████████████████████████████████████████████████████▉                    | 209/251 [00:09<00:01, 25.86it/s]
# Original number of lane 632
# Left lane line 20
# Right lane line 138
# Original number of lane 540
# Left lane line 21
# Right lane line 114
# Original number of lane 548
# Left lane line 20
# Right lane line 117
#  84%|█████████████████████████████████████████████████████████████████████████████████████████████████████▎                  | 212/251 [00:09<00:01, 26.55it/s]
# Original number of lane 516
# Left lane line 17
# Right lane line 112
# Original number of lane 528
# Left lane line 15
# Right lane line 117
# Original number of lane 592
# Left lane line 21
# Right lane line 127
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊                 | 215/251 [00:09<00:01, 27.05it/s]
# Original number of lane 520
# Left lane line 18
# Right lane line 112
# Original number of lane 480
# Left lane line 15
# Right lane line 105
# Original number of lane 500
# Left lane line 14
# Right lane line 111
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████▏               | 218/251 [00:10<00:01, 26.54it/s]
# Original number of lane 484
# Left lane line 18
# Right lane line 103
# Original number of lane 504
# Left lane line 14
# Right lane line 112
# Original number of lane 576
# Left lane line 20
# Right lane line 124
#  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▋              | 221/251 [00:10<00:01, 27.05it/s]
# Original number of lane 484
# Left lane line 29
# Right lane line 92
# Original number of lane 544
# Left lane line 17
# Right lane line 119
# Original number of lane 496
# Left lane line 14
# Right lane line 110
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████             | 224/251 [00:10<00:01, 26.33it/s]
# Original number of lane 524
# Left lane line 19
# Right lane line 112
# Original number of lane 512
# Left lane line 24
# Right lane line 104
# Original number of lane 440
# Left lane line 23
# Right lane line 87
#  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▌           | 227/251 [00:10<00:00, 26.96it/s]
# Original number of lane 496
# Left lane line 23
# Right lane line 101
# Original number of lane 500
# Left lane line 25
# Right lane line 100
# Original number of lane 468
# Left lane line 24
# Right lane line 93
# Original number of lane 544
# Left lane line 29
# Right lane line 107
#  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▍         | 231/251 [00:10<00:00, 27.83it/s]
# Original number of lane 632
# Left lane line 41
# Right lane line 117
# Original number of lane 520
# Left lane line 29
# Right lane line 101
# Original number of lane 672
# Left lane line 46
# Right lane line 122
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▊        | 234/251 [00:10<00:00, 28.28it/s]
# Original number of lane 664
# Left lane line 49
# Right lane line 117
# Original number of lane 552
# Left lane line 41
# Right lane line 97
# Original number of lane 652
# Left lane line 48
# Right lane line 115
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎      | 237/251 [00:10<00:00, 28.61it/s]
# Original number of lane 476
# Left lane line 28
# Right lane line 91
# Original number of lane 588
# Left lane line 39
# Right lane line 108
# Original number of lane 584
# Left lane line 57
# Right lane line 89
#  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋     | 240/251 [00:10<00:00, 28.77it/s]
# Original number of lane 504
# Left lane line 37
# Right lane line 89
# Original number of lane 608
# Left lane line 49
# Right lane line 103
# Original number of lane 584
# Left lane line 46
# Right lane line 100
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 243/251 [00:10<00:00, 28.96it/s]
# Original number of lane 656
# Left lane line 60
# Right lane line 104
# Original number of lane 580
# Left lane line 32
# Right lane line 113
# Original number of lane 540
# Left lane line 44
# Right lane line 91
# Original number of lane 576
# Left lane line 53
# Right lane line 91
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████  | 247/251 [00:11<00:00, 29.03it/s]
# Original number of lane 580
# Left lane line 37
# Right lane line 108
# Original number of lane 764
# Left lane line 71
# Right lane line 120
# Original number of lane 612
# Left lane line 40
# Right lane line 113
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌| 250/251 [00:11<00:00, 29.23it/s]
# Original number of lane 512
# Left lane line 25
# Right lane line 103
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 251/251 [00:11<00:00, 22.30it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: challenge.mp4
#
# Wall time: 12 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="challenge.mp4">
# </video>
